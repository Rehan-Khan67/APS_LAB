# %% [markdown]
# <a href="https://colab.research.google.com/github/Rehan-Khan67/APS_LAB/blob/main/Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minimum Cost Spanning Tree
# Problem Description:
# A spanning tree of a graph can be defined as a graph with minimal set of edges that connect all vertices. A minimum spanning tree of a graph is a spanning tree of the graph with least weight (where the weight is computed by adding the weights of all the edges in the spanning tree). In general, a graph can have multiple minimum spanning trees. The problem is to find a minimum spanning tree of a graph.

# %% [markdown]
# This implementation uses a dictionary to represent the weighted graph, where the vertices are keys, and the values are dictionaries containing their adjacent vertices and their weights.
#
# Please note that this implementation assumes that the input graph is connected and weighted.
#
# First, let's create a simple graph to demonstrate Prim's algorithm:

# %%
graph = {
    "A": {"B": 10, "C": 15, "D": 20},
    "B": {"A": 10, "C": 12},
    "C": {"A": 15, "B": 12, "D": 18},
    "D": {"A": 20, "C": 18},
}

# %% [markdown]
# Now, let's implement Prim's algorithm:

# %%
def prim_algorithm(graph):
    start_vertex = list(graph.keys())[0]
    visited = {start_vertex}
    edges = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        chosen_edge = None
        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited and weight < min_edge:
                    min_edge = weight
                    chosen_edge = (vertex, adj_vertex, weight)

        if chosen_edge:
            v1, v2, weight = chosen_edge
            edges.append((v1, v2, weight))
            visited.add(v2)
            min_weight += weight

    return edges, min_weight

mst_edges, total_weight = prim_algorithm(graph)
print("MST Edges:", mst_edges)
print("Total Weight:", total_weight)
# Out:
# MST Edges: [('A', 'B', 10), ('B', 'C', 12), ('C', 'D', 18)]
# Total Weight: 40

# %% [markdown]
# Now, let's run the Prim's algorithm on the example graph:
# Keep in mind that this example uses a simple representation of a graph, but for more complex cases, you might want to use a library such as NetworkX to represent and manipulate graphs.

# %%
mst, min_weight = prim_algorithm(graph)
print("Minimum Spanning Tree: ", mst)
print("Minimum Weight: ", min_weight)
# Out:
# Minimum Spanning Tree:  {'A': [], 'B': [], 'C': [], 'D': []}
# Minimum Weight:  50

# %% [markdown]
# Take Differnt example of input graph as discussed in lecture slide and use above code to verify the output

# %%
# your sample input of graph
graph = {
    "A": {"B": 4, "H": 8},
    "B": {"A": 4, "H": 11, "C": 8},
    "C": {"B": 8, "I": 2, "F": 4, "D": 7},
    "D": {"C": 7, "F": 14, "E": 9},
    "E": {"D": 9, "F": 10},
    "F": {"C": 4, "D": 14, "E": 10, "G": 2},
    "G": {"F": 2, "I": 6, "H": 1},
    "H": {"A": 8, "B": 11, "G": 1, "I": 7},
    "I": {"C": 2, "G": 6, "H": 7},
}

# %%
#run prims algorithm for sample input
def prim_algorithm(graph):
    start_vertex = list(graph.keys())[0]
    visited = {start_vertex}
    edges = []
    min_weight = 0

    while len(visited) < len(graph):
        min_edge = float('inf')
        chosen_edge = None

        for vertex in visited:
            for adj_vertex, weight in graph[vertex].items():
                if adj_vertex not in visited and weight < min_edge:
                    min_edge = weight
                    chosen_edge = (vertex, adj_vertex, weight)

        if chosen_edge:
            v1, v2, weight = chosen_edge
            edges.append((v1, v2, weight))
            visited.add(v2)
            min_weight += weight

    return edges, min_weight

mst_edges, total_weight = prim_algorithm(graph)
print("Prim's MST Edges:", mst_edges)
print("Prim's Total Weight:", total_weight)
# Out:
# Prim's MST Edges: [('A', 'B', 4), ('B', 'C', 8), ('C', 'I', 2), ('C', 'F', 4), ('F', 'G', 2), ('G', 'H', 1), ('C', 'D', 7), ('D', 'E', 9)]
# Prim's Total Weight: 37

# %% [markdown]
# Use same apporach for Kruskal's algorithm

# %%
# implement Kruskal's algorithm
def kruskal_algorithm(graph):
    edges = []
    for v1 in graph:
        for v2, weight in graph[v1].items():
            if (v2, v1, weight) not in edges:
                edges.append((v1, v2, weight))
    edges.sort(key=lambda x: x[2])

    parent = {}
    rank = {}

    def find(v):
        if parent[v] != v:
            parent[v] = find(parent[v])
        return parent[v]

    def union(v1, v2):
        root1, root2 = find(v1), find(v2)
        if root1 != root2:
            if rank[root1] < rank[root2]:
                parent[root1] = root2
            elif rank[root1] > rank[root2]:
                parent[root2] = root1
            else:
                parent[root2] = root1
                rank[root1] += 1

    for vertex in graph:
        parent[vertex] = vertex
        rank[vertex] = 0

    mst = []
    total_weight = 0

    for v1, v2, weight in edges:
        if find(v1) != find(v2):
            union(v1, v2)
            mst.append((v1, v2, weight))
            total_weight += weight

    return mst, total_weight

mst_edges_k, total_weight_k = kruskal_algorithm(graph)
print("Kruskal's MST Edges:", mst_edges_k)
print("Kruskal's Total Weight:", total_weight_k)
# Out:
# Kruskal's MST Edges: [('G', 'H', 1), ('C', 'I', 2), ('F', 'G', 2), ('A', 'B', 4), ('C', 'F', 4), ('C', 'D', 7), ('A', 'H', 8), ('D', 'E', 9)]
# Kruskal's Total Weight: 37
